# %% [markdown]
# # Data Mining and Machine Learning Lab
# ## Experiment 1

# %% [markdown]
# ### Importing the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load the file to your python program in to a data frame DF1.

# %%
df1 = pd.read_csv(r"D:\study material\VIT_Data_Science\Winter_Sem\Data Mining and Machine Learning Lab\Class_notes\18_Dec_ML_exp1\housepricedata.csv")

# %%
df1
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0        8450            7            5          856         2         1
# 1        9600            6            8         1262         2         0
# 2       11250            7            5          920         2         1
# 3        9550            7            5          756         1         0
# 4       14260            8            5         1145         2         1
# ...       ...          ...          ...          ...       ...       ...
# 1455     7917            6            5          953         2         1
# 1456    13175            6            6         1542         2         0
# 1457     9042            7            9         1152         2         0
# 1458     9717            5            6         1078         1         0
# 1459     9937            5            6         1256         1         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# ...

# %% [markdown]
# ### First five observations from your dataset

# %%
df1.head(5)
# Out:
#    LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0     8450            7            5          856         2         1
# 1     9600            6            8         1262         2         0
# 2    11250            7            5          920         2         1
# 3     9550            7            5          756         1         0
# 4    14260            8            5         1145         2         1
#
#    BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0             3             8           0         548                 1
# 1             3             6           1         460                 1
# 2             3             6           1         608                 1
# 3             3             7           1         642                 0
# 4             4             9           1         836                 1

# %% [markdown]
# ### Last five observations from our dataset

# %%
df1.tail(5)
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 1455     7917            6            5          953         2         1
# 1456    13175            6            6         1542         2         0
# 1457     9042            7            9         1152         2         0
# 1458     9717            5            6         1078         1         0
# 1459     9937            5            6         1256         1         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 1455             3             7           1         460                 1
# 1456             3             7           2         500                 1
# 1457             4             9           2         252                 1
# 1458             2             5           0         240                 0
# 1459             3             6           0         276                 0

# %% [markdown]
# ###  Shape of your dataset

# %%
df1.shape
# Out:
# (1460, 11)

# %% [markdown]
# ### info of your dataset

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LotArea           1460 non-null   int64
#  1   OverallQual       1460 non-null   int64
#  2   OverallCond       1460 non-null   int64
#  3   TotalBsmtSF       1460 non-null   int64
#  4   FullBath          1460 non-null   int64
#  5   HalfBath          1460 non-null   int64
#  6   BedroomAbvGr      1460 non-null   int64
#  7   TotRmsAbvGrd      1460 non-null   int64
#  8   Fireplaces        1460 non-null   int64
#  9   GarageArea        1460 non-null   int64
#  10  AboveMedianPrice  1460 non-null   int64
# dtypes: int64(11)
# memory usage: 125.6 KB

# %% [markdown]
# ###  Create a new dataframe DF2 with the first 100 observations of your dataset with only the columns `LotArea` and `BedroomAbvGr` [Use iloc operator]

# %%
df2 = (df1.iloc[0:100])[['LotArea','BedroomAbvGr']]

# %%
df2
# Out:
#     LotArea  BedroomAbvGr
# 0      8450             3
# 1      9600             3
# 2     11250             3
# 3      9550             3
# 4     14260             4
# ..      ...           ...
# 95     9765             3
# 96    10264             3
# 97    10921             3
# 98    10625             2
# 99     9320             3
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Write or export your dataset DF2 to a csv file DF11.csv and save it.

# %%
df2.to_csv('DF11.csv')

# %% [markdown]
# ###  Find the maximum and minimum of the `LotArea` column for your dataset DF1

# %%
print("Maximum of LotArea column is:",df1['LotArea'].max())
# Out:
# Maximum of LotArea column is: 215245

# %%
print("Minimum of LotArea column is:",df1['LotArea'].min())
# Out:
# Minimum of LotArea column is: 1300

# %% [markdown]
# ###  Find the observations from your dataset with LotArea > 10650 from your DF1 dataframe.

# %%
df1[df1['LotArea']>10650]
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 2       11250            7            5          920         2         1
# 4       14260            8            5         1145         2         1
# 5       14115            5            5          796         1         1
# 10      11200            5            5         1040         1         0
# 11      11924            9            5         1175         3         0
# ...       ...          ...          ...          ...       ...       ...
# 1442    11003           10            5         1017         2         1
# 1446    26142            5            7         1188         1         0
# 1448    11767            4            7          560         1         1
# 1453    17217            5            5         1140         1         0
# 1456    13175            6            6         1542         2         0
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# ...

# %% [markdown]
# ### Find the mean, median of your column `TotalBsmtSF` and find the unique entries (non-repeated ones)

# %%
print("Mean of the column TotalBsmtSf is:",df1.TotalBsmtSF.mean())
# Out:
# Mean of the column TotalBsmtSf is: 1057.4294520547944

# %%
print("Median of the column TotalBsmtSf is:",df1.TotalBsmtSF.median())
# Out:
# Median of the column TotalBsmtSf is: 991.5

# %%
print("Unique of the column TotalBsmtSf is:\n",df1.TotalBsmtSF.unique())
# Out:
# Unique of the column TotalBsmtSf is:
#  [ 856 1262  920  756 1145  796 1686 1107  952  991 1040 1175  912 1494
#  1253  832 1004    0 1114 1029 1158  637 1777 1060 1566  900 1704 1484
#   520  649 1228 1234 1398 1561 1117 1097 1297 1057 1088 1350  840  938
#  1150 1752 1434 1656  736  955  794  816 1842  384 1425  970  860 1410
#   780  530 1370  576 1143 1947 1453  747 1304 2223  845 1086  462  672
#  1768  440  896 1237 1563 1065 1288  684  612 1013  990 1235  876 1214
#   824  680 1588  960  458  950 1610  741 1226 1053  641  789  793 1844
#   994 1264 1809 1028  729 1092 1125 1673  728  732 1080 1199 1362 1078
#   660 1008  924  992 1063 1267 1461 1907  928  864 1734  910 1490 1728
#   715  884  969 1710  825 1602 1200  572  774 1392 1232 1572 1541  882
#  1149  644 1617 1582  720 1064 1606 1202 1151 1052 2216  968  504 1188
#  1593  853  725 1431  855 1726 1360  755 1713 1121 1196  617  848 1424
#  1140 1100 1157 1212  689 1070 1436  686  798 1248 1498 1010  713 2392
# ...

# %% [markdown]
# ### Sort the dataset DF1 according to the `TotalBsmtSF` column of your dataset DF1 in ascending and descending order

# %%
##sorting in descending order
df1.sort_values(by=['TotalBsmtSF'],ascending=False)
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 1298    63887           10            5         6110         2         1
# 332     10655            8            5         3206         2         0
# 496     12692            8            5         3200         3         0
# 523     40094           10            5         3138         3         1
# 440     15431           10            5         3094         2         0
# ...       ...          ...          ...          ...       ...       ...
# 1412     7200            4            5            0         2         0
# 1179     8335            5            5            0         1         0
# 102      7018            5            5            0         2         0
# 259     12702            5            5            0         1         0
# 1048    21750            5            4            0         1         0
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# ...

# %%
#sorted in ascending order
df1.sort_values(by=['TotalBsmtSF'])
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 646      7200            5            5            0         1         0
# 1035    11500            4            3            0         1         0
# 392      8339            5            7            0         1         0
# 749      8405            4            3            0         2         0
# 1011     9825            5            5            0         2         0
# ...       ...          ...          ...          ...       ...       ...
# 440     15431           10            5         3094         2         0
# 523     40094           10            5         3138         3         1
# 496     12692            8            5         3200         3         0
# 332     10655            8            5         3206         2         0
# 1298    63887           10            5         6110         2         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# ...

# %% [markdown]
# ### Find the empty cells in ’GarageArea’ column of your dataset DF1 and fill it with the average value of the column `GarageArea`

# %%
df1['GarageArea'].isnull().sum()
# Out:
# 0

# %%
df1['GarageArea'].fillna(df1['GarageArea'].mean(),inplace=True)

# %% [markdown]
# ### Replace the column named Above median price in your dataframe with 1’s where ever you have Yes and 0 where ever you have No

# %%
df1['AboveMedianPrice'].replace({'Yes':1,'no':0},inplace=True)

# %%
df1['AboveMedianPrice']
# Out:
# 0       1
# 1       1
# 2       1
# 3       0
# 4       1
#        ..
# 1455    1
# 1456    1
# 1457    1
# 1458    0
# 1459    0
# Name: AboveMedianPrice, Length: 1460, dtype: int64

# %% [markdown]
# ### Draw a scatterplot with columns ’GarageArea’ on x axis and ’LotArea’ on y-axis

# %%
plt.scatter(df1['GarageArea'],df1['LotArea'])
plt.title("Scatter plot of GarageArea and LotArea")
plt.xlabel("GarageArea")
plt.ylabel("LotArea")
plt.show()

# %%
import seaborn as sns
sns.scatterplot(x=df1['GarageArea'],y = df1['LotArea'])
plt.title("Scatter plot of GarageArea and LotArea")
plt.xlabel("GarageArea")
plt.ylabel("LotArea")
plt.show()

# %% [markdown]
# ###  Drop the column ’GarageArea’ from your dataset DF1

# %%
df1.drop('GarageArea',axis=1,inplace=True)

# %%
df1
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0        8450            7            5          856         2         1
# 1        9600            6            8         1262         2         0
# 2       11250            7            5          920         2         1
# 3        9550            7            5          756         1         0
# 4       14260            8            5         1145         2         1
# ...       ...          ...          ...          ...       ...       ...
# 1455     7917            6            5          953         2         1
# 1456    13175            6            6         1542         2         0
# 1457     9042            7            9         1152         2         0
# 1458     9717            5            6         1078         1         0
# 1459     9937            5            6         1256         1         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  AboveMedianPrice
# ...

# %% [markdown]
# ## Q1. Now, normalize the columns of the dataset1 using the above technique and save it to a new csv file DF3.csv

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
col_name = df1.columns[:]
x = df1.loc[:, col_name]
x = pd.DataFrame(data = min_max_scaler.fit_transform(x), columns = col_name)
print(x)
x.to_csv('df3.csv')
# Out:
#        LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0     0.033420     0.666667        0.500     0.140098  0.666667       0.5
# 1     0.038795     0.555556        0.875     0.206547  0.666667       0.0
# 2     0.046507     0.666667        0.500     0.150573  0.666667       0.5
# 3     0.038561     0.666667        0.500     0.123732  0.333333       0.0
# 4     0.060576     0.777778        0.500     0.187398  0.666667       0.5
# ...        ...          ...          ...          ...       ...       ...
# 1455  0.030929     0.555556        0.500     0.155974  0.666667       0.5
# 1456  0.055505     0.555556        0.625     0.252373  0.666667       0.0
# 1457  0.036187     0.666667        1.000     0.188543  0.666667       0.0
# 1458  0.039342     0.444444        0.625     0.176432  0.333333       0.0
# 1459  0.040370     0.444444        0.625     0.205565  0.333333       0.5
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  AboveMedianPrice
# ...

# %% [markdown]
# ### Q2. Now normalize the whole data to the range (2,3) using Min-Max normalization

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(2,3))
col_name = df1.columns[:]
x = df1.loc[:, col_name]
x = pd.DataFrame(data = min_max_scaler.fit_transform(x), columns = col_name)
print(x)
# Out:
#        LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0     2.033420     2.666667        2.500     2.140098  2.666667       2.5
# 1     2.038795     2.555556        2.875     2.206547  2.666667       2.0
# 2     2.046507     2.666667        2.500     2.150573  2.666667       2.5
# 3     2.038561     2.666667        2.500     2.123732  2.333333       2.0
# 4     2.060576     2.777778        2.500     2.187398  2.666667       2.5
# ...        ...          ...          ...          ...       ...       ...
# 1455  2.030929     2.555556        2.500     2.155974  2.666667       2.5
# 1456  2.055505     2.555556        2.625     2.252373  2.666667       2.0
# 1457  2.036187     2.666667        3.000     2.188543  2.666667       2.0
# 1458  2.039342     2.444444        2.625     2.176432  2.333333       2.0
# 1459  2.040370     2.444444        2.625     2.205565  2.333333       2.5
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  AboveMedianPrice
# ...

# %% [markdown]
# ## Q3. Now do decimal scaling for the original column data of the column LotArea of your initial dataframe and print the results.

# %%
max_abs_values = abs(df1.max())

# %%
max_abs_values
# Out:
# LotArea             215245
# OverallQual             10
# OverallCond              9
# TotalBsmtSF           6110
# FullBath                 3
# HalfBath                 2
# BedroomAbvGr             8
# TotRmsAbvGrd            14
# Fireplaces               3
# AboveMedianPrice         1
# dtype: int64

# %%
df88 = df1['LotArea'].apply(lambda x : x/10**(len(str(max_abs_values['LotArea']))))

# %%
df88
# Out:
# 0       0.008450
# 1       0.009600
# 2       0.011250
# 3       0.009550
# 4       0.014260
#           ...
# 1455    0.007917
# 1456    0.013175
# 1457    0.009042
# 1458    0.009717
# 1459    0.009937
# Name: LotArea, Length: 1460, dtype: float64

# %% [markdown]
# ### Q4. Now try to standardize the whole data in the dataframe and print thedataframe.

# %%
from sklearn import preprocessing
standard_scaler = preprocessing.StandardScaler()
col_name = df1.columns
x = df1.loc[:, col_name]
x = pd.DataFrame(data = standard_scaler.fit_transform(x), columns = col_name)
print(x)
# Out:
#        LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0    -0.207142     0.651479    -0.517200    -0.459303  0.789741  1.227585
# 1    -0.091886    -0.071836     2.179628     0.466465  0.789741 -0.761621
# 2     0.073480     0.651479    -0.517200    -0.313369  0.789741  1.227585
# 3    -0.096897     0.651479    -0.517200    -0.687324 -1.026041 -0.761621
# 4     0.375148     1.374795    -0.517200     0.199680  0.789741  1.227585
# ...        ...          ...          ...          ...       ...       ...
# 1455 -0.260560    -0.071836    -0.517200    -0.238122  0.789741  1.227585
# 1456  0.266407    -0.071836     0.381743     1.104925  0.789741 -0.761621
# 1457 -0.147810     0.651479     3.078570     0.215641  0.789741 -0.761621
# 1458 -0.080160    -0.795151     0.381743     0.046905 -1.026041 -0.761621
# 1459 -0.058112    -0.795151     0.381743     0.452784 -1.026041  1.227585
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  AboveMedianPrice
# ...

# %%
x
# Out:
#        LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0    -0.207142     0.651479    -0.517200    -0.459303  0.789741  1.227585
# 1    -0.091886    -0.071836     2.179628     0.466465  0.789741 -0.761621
# 2     0.073480     0.651479    -0.517200    -0.313369  0.789741  1.227585
# 3    -0.096897     0.651479    -0.517200    -0.687324 -1.026041 -0.761621
# 4     0.375148     1.374795    -0.517200     0.199680  0.789741  1.227585
# ...        ...          ...          ...          ...       ...       ...
# 1455 -0.260560    -0.071836    -0.517200    -0.238122  0.789741  1.227585
# 1456  0.266407    -0.071836     0.381743     1.104925  0.789741 -0.761621
# 1457 -0.147810     0.651479     3.078570     0.215641  0.789741 -0.761621
# 1458 -0.080160    -0.795151     0.381743     0.046905 -1.026041 -0.761621
# 1459 -0.058112    -0.795151     0.381743     0.452784 -1.026041  1.227585
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  AboveMedianPrice
# ...

# %% [markdown]
# ## Train Test splitting of data for model training.

# %% [markdown]
# ###  Now perfrom 70:30 train test split for our dataframe data with the target  variable or output variable as LotArea and print the training and testing data which may be we can use for fitting a model for this data. Say like trying to predict the LotArea for a house based on all the other features.

# %%
from sklearn.model_selection import train_test_split
x =df1.drop('LotArea', axis=1)
y = df1['LotArea']
#Split the data into training and testing sets (70% train, 30% test)
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.3, random_state=42)
#Print the testing and training data
print("Training Features:\n", x_train)
print("Testing Features:\n", x_test)
print("Training Target:\n", y_train)
print("Testing Target:\n", y_test)
# Out:
# Training Features:
#        OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  BedroomAbvGr  \
# 135             7            6         1304         2         0             3
# 1452            5            5          547         1         0             2
# 762             7            5          756         2         1             3
# 932             9            5         1905         2         0             3
# 435             7            6          799         2         1             3
# ...           ...          ...          ...       ...       ...           ...
# 1095            6            5         1314         2         0             3
# 1130            4            3         1122         2         0             4
# 1294            5            7          864         1         0             2
# 860             7            8          912         1         1             3
# 1126            7            5         1373         2         0             2
#
# ...

# %%
# Linear Regression model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
model = LinearRegression()
model.fit(x_train, y_train)

# Predicting the LotArea for test data
y_pred = model.predict(x_test)

# Evaluating the model's performance
mse = mean_squared_error(y_test, y_pred)  # Mean Squared Error
r2 = r2_score(y_test, y_pred)            # R-squared score

print("Model Coefficients:", model.coef_)
print("Model Intercept:", model.intercept_)
print("Mean Squared Error:", mse)
print("R-squared Score:", r2)

results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(results)
# Out:
# Model Coefficients: [-1784.57317854   535.39223068     6.34890747   105.64506875
#   -350.6656404    499.86480782   514.75964975  3611.59648719
#   2444.37464586]
# Model Intercept: 3657.748961708652
# Mean Squared Error: 31147397.821340438
# R-squared Score: 0.03359678635359464
#       Actual     Predicted
# 892     8414   8650.738138
# 1105   12256  17007.199705
# 413     8960  11637.704604
# 522     5000  15609.753689
# 1036   12898  10914.330395
# ...      ...           ...
# 331     8176   9345.480133
# 323     5820  14658.395143
# 650     8125   6947.662984
# 439    12354   6784.657486
# 798    13518  19797.199861
#
# [438 rows x 2 columns]
